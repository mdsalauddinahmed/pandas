# %%
import pandas as pd
dic={"a":[1,2,3,4,5],"b":[6,7,8,9,0],"c":[12,13,14,15,16]}
a=pd.DataFrame(dic)
a
a.to_csv("first_csv1.csv",index=False)

# %%
dic={"a":[1,2,3,4,5],"b":[6,7,8,9,0],"c":[12,13,14,15,16]}
a=pd.DataFrame(dic)
a
a.to_csv("first_csv2.csv",index=False,header=[1,2,3])

# %% [markdown]
# #read csv

# %%
csv_1=pd.read_csv("C:\\Users\\Amir\\Downloads\\Retail_sales.csv")
csv_1
# Out:
#          Store ID  Product ID        Date  Units Sold  Sales Revenue (USD)  \
# 0      Spearsland    52372247  2022-01-01           9              2741.69
# 1      Spearsland    52372247  2022-01-02           7              2665.53
# 2      Spearsland    52372247  2022-01-03           1               380.79
# 3      Spearsland    52372247  2022-01-04           4              1523.16
# 4      Spearsland    52372247  2022-01-05           2               761.58
# ...           ...         ...         ...         ...                  ...
# 29995  Spearsland    50239115  2022-01-25           5              2501.15
# 29996  Spearsland    50239115  2022-01-26           3              1500.69
# 29997  Spearsland    50239115  2022-01-27           6              3001.38
# 29998  Spearsland    50239115  2022-01-28           5              2501.15
# 29999  Spearsland    50239115  2022-01-29           3              1425.66
#
#        Discount Percentage  Marketing Spend (USD)  \
# ...

# %%
csv_2=pd.read_csv("C:\\Users\\Amir\\Downloads\\Retail_sales.csv",nrows=5)
csv_2
# Out:
#      Store ID  Product ID        Date  Units Sold  Sales Revenue (USD)  \
# 0  Spearsland    52372247  2022-01-01           9              2741.69
# 1  Spearsland    52372247  2022-01-02           7              2665.53
# 2  Spearsland    52372247  2022-01-03           1               380.79
# 3  Spearsland    52372247  2022-01-04           4              1523.16
# 4  Spearsland    52372247  2022-01-05           2               761.58
#
#    Discount Percentage  Marketing Spend (USD)             Store Location  \
# 0                   20                     81                   Tanzania
# 1                    0                      0                 Mauritania
# 2                    0                      0  Saint Pierre and Miquelon
# 3                    0                      0                  Australia
# 4                    0                      0                  Swaziland
#
#   Product Category Day of the Week  Holiday Effect
# ...

# %%
csv_2=pd.read_csv("C:\\Users\\Amir\\Downloads\\Retail_sales.csv",nrows=5,usecols=["Store ID","Discount Percentage"])
csv_2
# Out:
#      Store ID  Discount Percentage
# 0  Spearsland                   20
# 1  Spearsland                    0
# 2  Spearsland                    0
# 3  Spearsland                    0
# 4  Spearsland                    0

# %%
csv_2=pd.read_csv("C:\\Users\\Amir\\Downloads\\Retail_sales.csv",nrows=5,usecols=[0,3])
csv_2
# Out:
#      Store ID  Units Sold
# 0  Spearsland           9
# 1  Spearsland           7
# 2  Spearsland           1
# 3  Spearsland           4
# 4  Spearsland           2

# %%
csv_2=pd.read_csv("C:\\Users\\Amir\\Downloads\\Retail_sales.csv",skiprows=[0])
csv_2
# Out:
#        Spearsland  52372247  2022-01-01  9  2741.69  20   81  \
# 0      Spearsland  52372247  2022-01-02  7  2665.53   0    0
# 1      Spearsland  52372247  2022-01-03  1   380.79   0    0
# 2      Spearsland  52372247  2022-01-04  4  1523.16   0    0
# 3      Spearsland  52372247  2022-01-05  2   761.58   0    0
# 4      Spearsland  52372247  2022-01-06  8  3046.32   0   41
# ...           ...       ...         ... ..      ...  ..  ...
# 29994  Spearsland  50239115  2022-01-25  5  2501.15   0  100
# 29995  Spearsland  50239115  2022-01-26  3  1500.69   0    0
# 29996  Spearsland  50239115  2022-01-27  6  3001.38   0    0
# 29997  Spearsland  50239115  2022-01-28  5  2501.15   0    0
# 29998  Spearsland  50239115  2022-01-29  3  1425.66   5  190
#
#                                            Tanzania  Furniture   Saturday  \
# 0                                        Mauritania  Furniture     Sunday
# 1                         Saint Pierre and Miquelon  Furniture     Monday
# ...

# %%
csv_3=pd.read_csv("C:\\Users\\Amir\\Downloads\\Retail_sales.csv",index_col="Date")
csv_3
# Out:
#               Store ID  Product ID  Units Sold  Sales Revenue (USD)  \
# Date
# 2022-01-01  Spearsland    52372247           9              2741.69
# 2022-01-02  Spearsland    52372247           7              2665.53
# 2022-01-03  Spearsland    52372247           1               380.79
# 2022-01-04  Spearsland    52372247           4              1523.16
# 2022-01-05  Spearsland    52372247           2               761.58
# ...                ...         ...         ...                  ...
# 2022-01-25  Spearsland    50239115           5              2501.15
# 2022-01-26  Spearsland    50239115           3              1500.69
# 2022-01-27  Spearsland    50239115           6              3001.38
# 2022-01-28  Spearsland    50239115           5              2501.15
# 2022-01-29  Spearsland    50239115           3              1425.66
#
#             Discount Percentage  Marketing Spend (USD)  \
# Date
# 2022-01-01                   20                     81
# ...

# %%
csv_4=pd.read_csv("C:\\Users\\Amir\\Downloads\\Retail_sales.csv",header=2 )
csv_4
# Out:
#        Spearsland  52372247  2022-01-02  7  2665.53  0  0.1  \
# 0      Spearsland  52372247  2022-01-03  1   380.79  0    0
# 1      Spearsland  52372247  2022-01-04  4  1523.16  0    0
# 2      Spearsland  52372247  2022-01-05  2   761.58  0    0
# 3      Spearsland  52372247  2022-01-06  8  3046.32  0   41
# 4      Spearsland  52372247  2022-01-07  6  2284.74  0    0
# ...           ...       ...         ... ..      ... ..  ...
# 29993  Spearsland  50239115  2022-01-25  5  2501.15  0  100
# 29994  Spearsland  50239115  2022-01-26  3  1500.69  0    0
# 29995  Spearsland  50239115  2022-01-27  6  3001.38  0    0
# 29996  Spearsland  50239115  2022-01-28  5  2501.15  0    0
# 29997  Spearsland  50239115  2022-01-29  3  1425.66  5  190
#
#                                          Mauritania  Furniture     Sunday  \
# 0                         Saint Pierre and Miquelon  Furniture     Monday
# 1                                         Australia  Furniture    Tuesday
# ...

# %%
csv_5=pd.read_csv("C:\\Users\\Amir\\Downloads\\Retail_sales.csv",names=["col1","col2","col3","col4","col5"])
csv_5
# Out:
#                                                                                                       col1  \
# Store ID   Product ID Date       Units Sold Sales Revenue (USD) Discount Percentage  Marketing Spend (USD)
# Spearsland 52372247   2022-01-01 9          2741.69             20                                      81
#                       2022-01-02 7          2665.53             0                                        0
#                       2022-01-03 1          380.79              0                                        0
#                       2022-01-04 4          1523.16             0                                        0
# ...                                                                                                    ...
#            50239115   2022-01-25 5          2501.15             0                                      100
#                       2022-01-26 3          1500.69             0                                        0
# ...

# %%
csv_6=pd.read_csv("C:\\Users\\Amir\\Downloads\\Retail_sales.csv",header=None )
csv_6
# Out:
#                0           1           2           3                    4   \
# 0        Store ID  Product ID        Date  Units Sold  Sales Revenue (USD)
# 1      Spearsland    52372247  2022-01-01           9              2741.69
# 2      Spearsland    52372247  2022-01-02           7              2665.53
# 3      Spearsland    52372247  2022-01-03           1               380.79
# 4      Spearsland    52372247  2022-01-04           4              1523.16
# ...           ...         ...         ...         ...                  ...
# 29996  Spearsland    50239115  2022-01-25           5              2501.15
# 29997  Spearsland    50239115  2022-01-26           3              1500.69
# 29998  Spearsland    50239115  2022-01-27           6              3001.38
# 29999  Spearsland    50239115  2022-01-28           5              2501.15
# 30000  Spearsland    50239115  2022-01-29           3              1425.66
#
#                         5                      6   \
# ...

# %%
csv_=pd.read_csv("C:\\Users\\Amir\\Downloads\\Retail_sales.csv",dtype={"Sales Revenue (USD)":"int"})
csv_3
